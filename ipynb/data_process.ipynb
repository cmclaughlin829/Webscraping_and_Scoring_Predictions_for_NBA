# %%
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# ### Import data

# %%
nba = pd.read_csv('../data/gamelogs_advanced.csv', index_col=0)
nba.date_game = pd.to_datetime(nba.date_game,infer_datetime_format=True)

# %% [markdown]
# ### Change win loss to numeric

# %%
nba['w_l'] = np.where(nba['game_result'] == 'W', 1, 0)

# %% [markdown]
# ### Sort by season and team and create expanding mean columns

# %%
teams = nba.sort_values(['season', 'team'], ascending=[True, True])

# %%
unwanted_columns = ['team', 'season', 'game_season', 'date_game', 'game_location',
                    'opp_id', 'game_result']

columns_to_mean = [column for column in list(nba.columns) if column not in unwanted_columns]

# %%
def mean_expansion(df, column_list):
    for column in column_list:
        df[column+'_mean']=df.groupby(['season', 'team'])[column].transform(lambda x: x.expanding().mean().shift(1))
    return df

means = mean_expansion(teams, columns_to_mean)

# %%
filename = '../data/cleaned_stats.sav'
pickle.dump(means, open(filename, 'wb'))

# %% [markdown]
# ### Make new dataframe consisting of only columns to be merged with schedule

# %%
cols = list(means.columns.values)
new_cols = [cols[0]]+cols[2:4]+[cols[7]]+cols[58:]
new_means = means[new_cols].copy()

# %% [markdown]
# ## Create League Schedule

# %%
schedule = nba[['date_game', 'team', 'season', 'game_location', 
                'opp_id']].sort_values(by='date_game').reset_index(drop=True)

# %%
schedule['home_team'] = np.where(schedule['game_location'] == '@', schedule['opp_id'], schedule['team'])
schedule['away_team'] = np.where(schedule['game_location'] == '@', schedule['team'], schedule['opp_id'])

# %%
schedule.drop(['team', 'game_location', 'opp_id'], axis=1, inplace=True)

# %%
schedule.head()
# Out:
#    date_game  season home_team away_team
# 0 2007-10-30    2008       LAL       HOU
# 1 2007-10-30    2008       LAL       HOU
# 2 2007-10-30    2008       GSW       UTA
# 3 2007-10-30    2008       GSW       UTA
# 4 2007-10-30    2008       SAS       POR

# %%
schedule_new = schedule.drop_duplicates()

# %%
schedule_new.head()
# Out:
#    date_game  season home_team away_team
# 0 2007-10-30    2008       LAL       HOU
# 2 2007-10-30    2008       GSW       UTA
# 4 2007-10-30    2008       SAS       POR
# 6 2007-10-31    2008       ORL       MIL
# 7 2007-10-31    2008       MEM       SAS

# %%
filename = '../data/schedules.sav'
pickle.dump(schedule_new, open(filename, 'wb'))

# %% [markdown]
# ### Merge dataframes for model construction

# %%
data = schedule_new.merge(new_means, left_on=['home_team', 'date_game'], right_on=['team', 'date_game'])

# %%
home_column_name_dict = {column:'home_'+column for column in new_cols}
data = data.rename(columns = home_column_name_dict)

# %%
data.head()
# Out:
#   home_date_game  season home_team away_team home_team  home_game_season  \
# 0     2007-10-30    2008       LAL       HOU       LAL                 1
# 1     2007-10-30    2008       GSW       UTA       GSW                 1
# 2     2007-10-30    2008       SAS       POR       SAS                 1
# 3     2007-10-31    2008       ORL       MIL       ORL                 1
# 4     2007-10-31    2008       MEM       SAS       MEM                 1
#
#    home_pts  home_pts_mean  home_opp_pts_mean  home_fg_mean      ...        \
# 0        93            NaN                NaN           NaN      ...
# 1        96            NaN                NaN           NaN      ...
# 2       106            NaN                NaN           NaN      ...
# 3       102            NaN                NaN           NaN      ...
# 4       101            NaN                NaN           NaN      ...
#
#    home_blk_pct_mean  home_efg_pct_mean  home_tov_pct_mean  home_orb_pct_mean  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#    home_ft_rate_mean  home_opp_efg_pct_mean  home_opp_tov_pct_mean  \
# 0                NaN                    NaN                    NaN
# 1                NaN                    NaN                    NaN
# 2                NaN                    NaN                    NaN
# 3                NaN                    NaN                    NaN
# 4                NaN                    NaN                    NaN
#
#    home_drb_pct_mean  home_opp_ft_rate_mean  home_w_l_mean
# 0                NaN                    NaN            NaN
# 1                NaN                    NaN            NaN
# 2                NaN                    NaN            NaN
# 3                NaN                    NaN            NaN
# 4                NaN                    NaN            NaN
#
# [5 rows x 58 columns]

# %%
data = data.merge(new_means, left_on=['away_team', 'home_date_game'], right_on=['team', 'date_game'])

# %%
away_column_name_dict = {column:'away_'+column for column in new_cols}
data=data.rename(columns = away_column_name_dict)

# %%
data=data.rename(columns = {'home_date_game':'date_game'})

# %%
data.head(15)
# Out:
#     date_game  season home_team away_team  home_game_season  home_pts  \
# 0  2007-10-30    2008       LAL       HOU                 1        93
# 1  2007-10-30    2008       GSW       UTA                 1        96
# 2  2007-10-30    2008       SAS       POR                 1       106
# 3  2007-10-31    2008       ORL       MIL                 1       102
# 4  2007-10-31    2008       MEM       SAS                 1       101
# 5  2007-10-31    2008       DEN       SEA                 1       120
# 6  2007-10-31    2008       TOR       PHI                 1       106
# 7  2007-10-31    2008       NOH       SAC                 1       104
# 8  2007-10-31    2008       NJN       CHI                 1       112
# 9  2007-10-31    2008       IND       WAS                 1       119
# 10 2007-10-31    2008       CLE       DAL                 1        74
# 11 2007-11-01    2008       MIA       DET                 1        80
# 12 2007-11-01    2008       UTA       HOU                 2        95
# 13 2007-11-01    2008       SEA       PHO                 2        99
# 14 2007-11-02    2008       ORL       DET                 2        92
#
#     home_pts_mean  home_opp_pts_mean  home_fg_mean  home_fga_mean  \
# 0             NaN                NaN           NaN            NaN
# 1             NaN                NaN           NaN            NaN
# 2             NaN                NaN           NaN            NaN
# 3             NaN                NaN           NaN            NaN
# 4             NaN                NaN           NaN            NaN
# 5             NaN                NaN           NaN            NaN
# 6             NaN                NaN           NaN            NaN
# 7             NaN                NaN           NaN            NaN
# 8             NaN                NaN           NaN            NaN
# 9             NaN                NaN           NaN            NaN
# 10            NaN                NaN           NaN            NaN
# 11            NaN                NaN           NaN            NaN
# 12          117.0               96.0          41.0           90.0
# 13          103.0              120.0          40.0           96.0
# 14          102.0               83.0          32.0           73.0
#
#         ...       away_efg_pct_mean  away_tov_pct_mean  away_orb_pct_mean  \
# 0       ...                     NaN                NaN                NaN
# 1       ...                     NaN                NaN                NaN
# 2       ...                     NaN                NaN                NaN
# 3       ...                     NaN                NaN                NaN
# 4       ...                   0.506                7.5               27.3
# 5       ...                     NaN                NaN                NaN
# 6       ...                     NaN                NaN                NaN
# 7       ...                     NaN                NaN                NaN
# 8       ...                     NaN                NaN                NaN
# 9       ...                     NaN                NaN                NaN
# 10      ...                     NaN                NaN                NaN
# 11      ...                     NaN                NaN                NaN
# 12      ...                   0.500               17.0               31.6
# 13      ...                     NaN                NaN                NaN
# 14      ...                   0.425                9.7               25.5
#
#     away_ft_rate_mean  away_opp_efg_pct_mean  away_opp_tov_pct_mean  \
# 0                 NaN                    NaN                    NaN
# 1                 NaN                    NaN                    NaN
# 2                 NaN                    NaN                    NaN
# 3                 NaN                    NaN                    NaN
# 4               0.207                  0.538                   15.8
# 5                 NaN                    NaN                    NaN
# 6                 NaN                    NaN                    NaN
# 7                 NaN                    NaN                    NaN
# 8                 NaN                    NaN                    NaN
# 9                 NaN                    NaN                    NaN
# 10                NaN                    NaN                    NaN
# 11                NaN                    NaN                    NaN
# 12              0.284                  0.434                   11.1
# 13                NaN                    NaN                    NaN
# 14              0.288                  0.473                   17.2
#
#     away_drb_pct_mean  away_opp_ft_rate_mean  away_w_l_mean  score_margin
# 0                 NaN                    NaN            NaN            -2
# 1                 NaN                    NaN            NaN           -21
# 2                 NaN                    NaN            NaN             9
# 3                 NaN                    NaN            NaN            19
# 4                77.8                  0.167            1.0            -3
# 5                 NaN                    NaN            NaN            17
# 6                 NaN                    NaN            NaN             9
# 7                 NaN                    NaN            NaN            14
# 8                 NaN                    NaN            NaN             9
# 9                 NaN                    NaN            NaN             9
# 10                NaN                    NaN            NaN           -18
# 11                NaN                    NaN            NaN           -11
# 12               77.1                  0.355            1.0           -11
# 13                NaN                    NaN            NaN            -7
# 14               86.5                  0.120            1.0           -24
#
# [15 rows x 112 columns]

# %%
data = data.loc[:,~data.columns.duplicated()]

# %%
data['score_margin']=data['home_pts']-data['away_pts']

# %%
data.tail(16)
# Out:
#        date_game  season home_team away_team  home_game_season  home_pts  \
# 12043 2017-04-11    2017       SAC       PHO                81       129
# 12044 2017-04-11    2017       MIN       OKC                81        98
# 12045 2017-04-12    2017       ORL       DET                82       113
# 12046 2017-04-12    2017       HOU       MIN                82       123
# 12047 2017-04-12    2017       GSW       LAL                82       109
# 12048 2017-04-12    2017       IND       ATL                82       104
# 12049 2017-04-12    2017       OKC       DEN                82       105
# 12050 2017-04-12    2017       MEM       DAL                82        93
# 12051 2017-04-12    2017       CLE       TOR                82        83
# 12052 2017-04-12    2017       UTA       SAS                82       101
# 12053 2017-04-12    2017       LAC       SAC                82       115
# 12054 2017-04-12    2017       POR       NOP                82       100
# 12055 2017-04-12    2017       CHI       BRK                82       112
# 12056 2017-04-12    2017       NYK       PHI                82       114
# 12057 2017-04-12    2017       BOS       MIL                82       112
# 12058 2017-04-12    2017       MIA       WAS                82       110
#
#        home_pts_mean  home_opp_pts_mean  home_fg_mean  home_fga_mean  \
# 12043     102.575000         106.612500     37.775000      82.125000
# 12044     105.512500         106.562500     39.362500      84.312500
# 12045     100.925926         107.629630     38.234568      86.987654
# 12046     115.246914         109.469136     40.246914      87.098765
# 12047     115.975309         104.382716     43.098765      87.037037
# 12048     105.111111         105.555556     39.283951      84.555556
# 12049     106.617284         105.777778     39.432099      87.259259
# 12050     100.567901          99.987654     36.432099      83.580247
# 12051     110.679012         107.271605     40.086420      85.024691
# 12052     100.703704          96.765432     36.962963      79.481481
# 12053     108.592593         104.493827     39.493827      83.172840
# 12054     108.037037         108.530864     39.530864      86.098765
# 12055     102.753086         102.802469     38.617284      86.987654
# 12056     104.222222         107.950617     39.543210      88.555556
# 12057     107.962963         105.518519     38.604938      85.024691
# 12058     103.086420         102.111111     38.962963      85.790123
#
#            ...       away_efg_pct_mean  away_tov_pct_mean  away_orb_pct_mean  \
# 12043      ...                0.496086          13.040741          25.966667
# 12044      ...                0.501437          12.882500          27.748750
# 12045      ...                0.492889          10.546914          24.009877
# 12046      ...                0.510679          12.322222          27.165432
# 12047      ...                0.502099          12.960494          24.816049
# 12048      ...                0.505469          13.753086          23.551852
# 12049      ...                0.532099          12.812346          27.160494
# 12050      ...                0.505605          11.018519          17.882716
# 12051      ...                0.518025          11.077778          24.702469
# 12052      ...                0.525790          12.104938          23.491358
# 12053      ...                0.517210          13.261728          20.914815
# 12054      ...                0.504975          11.328395          18.293827
# 12055      ...                0.510815          14.230864          19.267901
# 12056      ...                0.502395          14.448148          22.000000
# 12057      ...                0.530025          12.645679          21.383951
# 12058      ...                0.529432          12.248148          23.872840
#
#        away_ft_rate_mean  away_opp_efg_pct_mean  away_opp_tov_pct_mean  \
# 12043           0.235222               0.526222              12.795062
# 12044           0.224125               0.513938              12.051250
# 12045           0.158704               0.518099              11.587654
# 12046           0.233037               0.535778              12.913580
# 12047           0.197938               0.543136              12.564198
# 12048           0.217173               0.507531              13.338272
# 12049           0.216519               0.533963              10.491358
# 12050           0.180593               0.531704              14.079012
# 12051           0.237309               0.509136              12.996296
# 12052           0.214062               0.491506              12.922222
# 12053           0.224173               0.528481              12.470370
# 12054           0.195025               0.509148              11.917284
# 12055           0.231901               0.515086              11.227160
# 12056           0.202531               0.514012              12.912346
# 12057           0.214062               0.520346              13.083951
# 12058           0.201556               0.525160              13.290123
#
#        away_drb_pct_mean  away_opp_ft_rate_mean  away_w_l_mean  score_margin
# 12043          76.423457               0.265481       0.296296            25
# 12044          79.168750               0.220113       0.575000            -2
# 12045          81.311111               0.199259       0.456790             4
# 12046          76.232099               0.214370       0.382716             5
# 12047          76.161728               0.216333       0.320988            15
# 12048          76.306173               0.179815       0.530864            18
# 12049          78.876543               0.196605       0.481481            -6
# 12050          78.011111               0.220420       0.395062            -7
# 12051          76.403704               0.225074       0.617284           -15
# 12052          77.785185               0.196210       0.753086             4
# 12053          76.561728               0.230383       0.395062            20
# 12054          76.892593               0.180407       0.407407            -3
# 12055          76.612346               0.215049       0.246914            39
# 12056          75.646914               0.236123       0.345679             1
# 12057          75.674074               0.218728       0.518519            18
# 12058          75.979012               0.216062       0.604938             8
#
# [16 rows x 112 columns]

# %%
filename = '../data/processed_data.sav'
pickle.dump(data, open(filename, 'wb'))
